# %% [markdown]
# # Python Básico

# %%
print('Olá mundo!')
# Out:
# Olá mundo!

# %%
print('Estou aprendendo Python')
# Out:
# Estou aprendendo Python

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
1 + 1
# Out:
# 2

# %%
10 - 2
# Out:
# 8

# %%
# esse é um comentário em Python

# %%
# multiplicação    
2 * 2
# Out:
# 4

# %%
# divisão 
10/2
# Out:
# 5.0

# %%
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
# criando uma variável do tipo string
frase = "Python para análise de dados"

# %%
frase[0]
# Out:
# 'P'

# %%
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a análise de dados'

# %%
frase[:17]
# Out:
# 'Python para análi'

# %%
frase.cont('dados')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-213b4fc7ff00> in <module>()
# ----> 1 frase.cont('dados')
#
# AttributeError: 'str' object has no attribute 'cont'

# %%
frase.count('dados')
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frases = frase.upper()

# %%
frase.replace("Python" ,"Frases")
# Out:
# 'Frases para análise de dados'

# %%
frases = frase.upper()

# %%
Frases = frase.upper()

# %%
frase
# Out:
# 'Python para análise de dados'

# %%
frases = frase.upper()

# %%
Frases = frase.upper()

# %%
Frases = frase.upper()

# %%
frase
# Out:
# 'Python para análise de dados'

# %%
Frases|
# Out:
#   File "<ipython-input-41-0828e25eb702>", line 1
#     Frases|
#            ^
# SyntaxError: invalid syntax

# %%
Frases
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'
